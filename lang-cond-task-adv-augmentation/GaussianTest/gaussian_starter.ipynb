# %% [markdown]
# # Generate the dataset
# ## We have 4 classes of 2D data points from each quadrant of the 2D plane
# ## We have an underltying functon that we would like top model, we do a symmetric sine function
# ## The dataset will have datapoints from each quadrant of the 2D plane sampled disproportionately
# ## The testing distributuion would be equivalent
# ## We will use 2 simple MLP's to model the function and the classifications

# %%
# All declarations

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.loggers import WandbLogger
import wandb
from PIL import Image
import imageio
from io import BytesIO

# %%
# All global variables

TRAIN_CLASS_SEGMENTS = [0.7,0.1,0.1,0.1]
CLASS_NAMES = ['0','1','2','3']
CLASS_COLORS = ['red','green','blue','yellow']
NDIM = 2
NSAMPLES = 10000
NCLASSES = len(CLASS_NAMES)
RANGE = [-2,2]
TRAIN_TEST_SPLIT = 0.8

# %%
# Creating a simple MLP

class MLP(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=2, output_size=1,softmax = False, sigmoid = False, tanh = False):
        super(MLP, self).__init__()

        if int(softmax) + int(sigmoid) + int(tanh) > 1:
            raise ValueError("Cannot have both sigmoid and softmax and tanh")
        
        self.num_layers = num_layers

        self.layers = torch.nn.ModuleList()
        self.layers.append(torch.nn.Linear(input_size, hidden_size))
        for i in range(self.num_layers):
            self.layers.append(torch.nn.ReLU())
            self.layers.append(torch.nn.Linear(hidden_size, hidden_size))

        self.layers.append(torch.nn.ReLU())
        self.layers.append(torch.nn.Linear(hidden_size, output_size))
        # if softmax:
        #     self.layers.append(torch.nn.Softmax(dim=1))
        if sigmoid:
            self.layers.append(torch.nn.Sigmoid())
        if tanh:
            self.layers.append(torch.nn.Tanh())
        self.network = torch.nn.Sequential(*self.layers)
    
    def forward(self, x):
        return self.network(x)

# %%
#Generating data

x_data = np.random.random(size = (NSAMPLES,2)) * (RANGE[1] - RANGE[0]) + RANGE[0]
y_class = np.zeros((NSAMPLES,))


# Class 1
class1 = np.where(np.logical_and(x_data[:,0] > 0, x_data[:,1] > 0))[0]
y_class[class1] = 0

# Class 2
class2 = np.where(np.logical_and(x_data[:,0] < 0, x_data[:,1] > 0))[0]
y_class[class2] = 1

# Class 3
class3 = np.where(np.logical_and(x_data[:,0] < 0, x_data[:,1] < 0))[0]
y_class[class3] = 2

# Class 4
class4 = np.where(np.logical_and(x_data[:,0] > 0, x_data[:,1] < 0))[0]
y_class[class4] = 3

# Underlying function is a gaussian distribution
y_labels = np.exp(-0.03*np.sum(x_data**2, axis = 1))

# %%
# Visualizing the data

plt.figure(figsize = (10,10))   
for i in range(NCLASSES):
    plt.scatter(x_data[y_class == i,0], x_data[y_class == i,1], c = CLASS_COLORS[i], label = CLASS_NAMES[i])
plt.legend()
plt.savefig('Dataclass.png')

# Visualizing the underlying function

plt.figure(figsize = (10,10))
plt.scatter(x_data[:,0], x_data[:,1], c = y_labels)
plt.savefig('Datafunc.png')

# %%
# Train test split 

train_test_split = int(TRAIN_TEST_SPLIT * NSAMPLES)
x_train, x_test = x_data[:train_test_split,:], x_data[train_test_split:,:]
y_class_train, y_class_test = y_class[:train_test_split], y_class[train_test_split:]
y_labels_train, y_labels_test = y_labels[:train_test_split], y_labels[train_test_split:]

# Creating the torch tensors

x_train = torch.tensor(x_train, dtype = torch.float32)
x_test = torch.tensor(x_test, dtype = torch.float32)
y_class_train = torch.tensor(y_class_train, dtype = torch.int64)
y_class_test = torch.tensor(y_class_test, dtype = torch.int64)
# Create one hot encoding for the class labels
# y_class_train = torch.nn.functional.one_hot(y_class_train, num_classes = NCLASSES).float()
# y_class_test = torch.nn.functional.one_hot(y_class_test, num_classes = NCLASSES).float()

y_labels_train = torch.tensor(y_labels_train, dtype = torch.float32)
y_labels_test = torch.tensor(y_labels_test, dtype = torch.float32)

print(x_train.shape, x_test.shape, y_class_train.shape, y_class_test.shape, y_labels_train.shape, y_labels_test.shape)

# Create the training and validation dataloaders from the torch tensors

train_dataset = torch.utils.data.TensorDataset(x_train, y_class_train,y_labels_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = 32, shuffle = True)

val_dataset = torch.utils.data.TensorDataset(x_test, y_class_test,y_labels_test)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle = True)
# Out:
# torch.Size([8000, 2]) torch.Size([2000, 2]) torch.Size([8000]) torch.Size([2000]) torch.Size([8000]) torch.Size([2000])

# %%
# Pytorch lightning module to train the models
#impor trace

from pdb import set_trace

class classTrainer(pl.LightningModule):

    # Declare the class models and the function models
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.model = MLP(input_size, hidden_size, output_size = output_size, num_layers = 3, softmax = True)
        self.func_model = MLP(input_size, hidden_size, output_size = 1, num_layers =3)
        self.loss = torch.nn.CrossEntropyLoss()
        self.funv_loss = torch.nn.MSELoss()
    
    def forward(self, x):
        return (self.model(x), self.func_model(x))
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-2)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y_class, y_labels = batch
        y_pred_class, y_pred_labels = self.forward(x)
        # print(y_pred_class.shape, y_class.shape)
        # print(y_pred_class[0])
        loss_class = self.loss(y_pred_class, y_class)
        
        loss_func = self.funv_loss(y_pred_labels, y_labels.unsqueeze(1))
        loss = loss_class + loss_func
        self.log('train_loss_class', loss_class.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        self.log('train_loss_func', loss_func.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x, y_class, y_labels = batch
        y_pred_class, y_pred_labels = self.forward(x)
        loss_class = self.loss(y_pred_class, y_class)
        loss_func = self.funv_loss(y_pred_labels, y_labels.unsqueeze(1))
        loss = loss_class + loss_func
        self.log('val_loss_class', loss_class.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        self.log('val_loss_func', loss_func.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        return loss

    def return_model_weights(self):
        return [self.model.state_dict(), self.func_model.state_dict()]

# %%
# Training the model
model = classTrainer(input_size=2,
                       hidden_size=128,
                        output_size=4)
logger = TensorBoardLogger("tb_logs", name="class")
wandb.finish()
wandb_logger = WandbLogger(project='lang-dataaugment', log_model='all')

trainer = pl.Trainer(max_epochs=100, devices=1, accelerator='gpu',logger=[logger,wandb_logger])
wandb_logger.watch(model, log='all')
trainer.fit(model, train_loader, val_loader)

# Saving the lightning module
torch.save(model.state_dict(), 'classmodel.pt')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: harshg5799. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>./wandb/run-20230831_184519-ax8f1d7s</code>
# Syncing run <strong><a href='https://wandb.ai/harshg5799/lang-dataaugment/runs/ax8f1d7s' target="_blank">electric-bee-23</a></strong> to <a href='https://wandb.ai/harshg5799/lang-dataaugment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/harshg5799/lang-dataaugment' target="_blank">https://wandb.ai/harshg5799/lang-dataaugment</a>
#  View run at <a href='https://wandb.ai/harshg5799/lang-dataaugment/runs/ax8f1d7s' target="_blank">https://wandb.ai/harshg5799/lang-dataaugment/runs/ax8f1d7s</a>
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# You are using a CUDA device ('NVIDIA RTX A5000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6]
#
#   | Name       | Type             | Params
# ------------------------------------------------
# 0 | model      | MLP              | 50.4 K
# 1 | func_model | MLP              | 50.0 K
# 2 | loss       | CrossEntropyLoss | 0
# 3 | funv_loss  | MSELoss          | 0
# ------------------------------------------------
# 100 K     Trainable params
# 0         Non-trainable params
# 100 K     Total params
# 0.402     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:486: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 99: 100%|██████████| 250/250 [00:03<00:00, 80.46it/s, v_num=1d7s, train_loss_class_step=0.000677, train_loss_func_step=4.74e-6, val_loss_class_step=1.07e-6, val_loss_func_step=1.88e-5, val_loss_class_epoch=0.0109, val_loss_func_epoch=1.21e-5, train_loss_class_epoch=0.00994, train_loss_func_epoch=3.49e-6]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 250/250 [00:03<00:00, 76.98it/s, v_num=1d7s, train_loss_class_step=0.000677, train_loss_func_step=4.74e-6, val_loss_class_step=1.07e-6, val_loss_func_step=1.88e-5, val_loss_class_epoch=0.0109, val_loss_func_epoch=1.21e-5, train_loss_class_epoch=0.00994, train_loss_func_epoch=3.49e-6]

# %%
# Learning the augmentation network
# Objective is simple, we take an desired input class and learn a neural network to augment data to the desired class
# Need to figure out the generqative prcoess in altent diffusioin, is the addition step a proabbailitic step or something more complex

class augmentTrainer(pl.LightningModule):

    # Declare the class models and the function models
    def __init__(self, input_size, hidden_size, output_size, class_modelweights = None, func_modelweights = None, T = 5):
        super().__init__()
        self.augment_model = MLP(input_size + NCLASSES, hidden_size, output_size = input_size, num_layers = 3, tanh = True)
        self.class_model = MLP(input_size, hidden_size, output_size = NCLASSES, num_layers = 3, softmax = True)
        self.class_model.load_state_dict(class_modelweights)
        self.class_model.requires_grad_(False)
        self.func_model = MLP(input_size, hidden_size, output_size = 1, num_layers =3)
        self.func_model.load_state_dict(func_modelweights)
        self.func_model.requires_grad_(False)
        self.T = 5 

        self.loss = torch.nn.CrossEntropyLoss()
    
    def forward(self, x,target_class):
        x_ = x.clone()
        #one hot target class'

        print(target_class.shape, target_class.type())
        target_class = torch.nn.functional.one_hot(target_class,
                                                    num_classes = NCLASSES).type(torch.float32)
        input = torch.cat((x_, target_class), dim = 1)
        for j in range(self.T):
            x_ = x_ + self.augment_model(input)
            input = torch.cat((x_, target_class),dim=1)

        return x_
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-2)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y_class, y_labels = batch
        
        x_mod = self.forward(x,y_class)
        y_pred_class = self.class_model(x_mod)
        loss_class = self.loss(y_pred_class, y_class)
        self.log('train_loss_class', loss_class.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        return loss_class
    
    def validation_step(self, batch, batch_idx):
        x, y_class, y_labels = batch
        y_pred_class = self.class_model(self.forward(x,y_class))
        loss_class = self.loss(y_pred_class, y_class)
        self.log('val_loss_class', loss_class.detach(), on_step=True, on_epoch=True, prog_bar=True, logger=True)
        return loss_class

    def return_model_weights(self):
        return self.augment_model.state_dict()

# %%
# Creating the modified dataset for the augmentation network, we take the original dataset and permute the class labels with it

x_train_aug = torch.repeat_interleave(x_train, NCLASSES, dim = 0)
x_test_aug = torch.repeat_interleave(x_test, NCLASSES, dim = 0)
y_train_class_aug = torch.cat([torch.tensor(np.zeros(y_class_train.shape[0]) + i) for i in range(NCLASSES)],
                              dim = 0).type(torch.LongTensor)
y_train_labels_aug = torch.repeat_interleave(y_labels_train, NCLASSES, dim = 0)
y_test_class_aug = torch.cat([torch.tensor(np.zeros(y_class_test.shape[0]) + i) for i in range(NCLASSES)]
                             ,dim = 0).type(torch.LongTensor)
y_test_labels_aug = torch.repeat_interleave(y_labels_test, NCLASSES, dim = 0)

print("Dataset Shapes:")
print(x_train_aug.shape, y_train_class_aug.shape, y_train_labels_aug.shape)
print(x_test_aug.shape, y_test_class_aug.shape, y_test_labels_aug.shape)

# Creating the dataloaders and the dataset
train_dataset_aug = torch.utils.data.TensorDataset(x_train_aug, y_train_class_aug, y_train_labels_aug)
train_loader_aug = torch.utils.data.DataLoader(train_dataset_aug, batch_size=2048, shuffle=True)
val_dataset_aug = torch.utils.data.TensorDataset(x_test_aug, y_test_class_aug, y_test_labels_aug)
val_loader_aug = torch.utils.data.DataLoader(val_dataset_aug, batch_size=2048, shuffle=True)

# Training the model

#Load the class and func model trained weights

model = classTrainer(input_size=2,
                    hidden_size=128,
                    output_size=4)

model.load_state_dict(torch.load('classmodel.pt'))
T = 3
aug_model = augmentTrainer(input_size=2,hidden_size=128,output_size=4, 
                       class_modelweights = model.return_model_weights()[0], 
                       func_modelweights = model.return_model_weights()[1],
                       T = T)

logger = TensorBoardLogger("tb_logs", name="augment")
wandb.finish()
wandb_logger = WandbLogger(project='lang-dataaugment', log_model='all')

trainer = pl.Trainer(max_epochs=100, devices=1, accelerator='gpu',logger=[logger,wandb_logger])
wandb_logger.watch(aug_model, log='all')
trainer.fit(aug_model, train_loader_aug, val_loader_aug)

# Save the lightning module
torch.save(aug_model.state_dict(), 'augmodel_T{}.pt'.format(T))
# Out:
# Dataset Shapes:
# torch.Size([32000, 2]) torch.Size([32000]) torch.Size([32000])
# torch.Size([8000, 2]) torch.Size([8000]) torch.Size([8000])
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss_class_epoch</td><td>█▃▃▂▃▂▂▂▂▂▂▂▁▃▂▂▁▁▃▂▁▂▃▁▁▁▂▂▁▂▂▂▁▁▂▁▁▁▂▁</td></tr><tr><td>train_loss_class_step</td><td>▃█▁▅▁▄▁▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▃▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss_func_epoch</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss_func_step</td><td>▃▁▁▁▁▃▂█▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▂▁▂▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▁▁▁▁▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▇▃▃▃█▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>val_loss_class_epoch</td><td>▆▄▂▃▂▂▂▂▂▂▁▃▁▁▃▁▆▁▄▂▁▁▂▂▁▁▂▂▂▁█▂▂▁▂▁▁▁▂▁</td></tr><tr><td>val_loss_class_step</td><td>▁▁▁█▃▁▁▁▁▁▂▁▁▁▁▁▂▁▅▁▁▂▁▁▁▁▁▁▂▁▁▁▁▂▁▃▁▁▁▂</td></tr><tr><td>val_loss_func_epoch</td><td>▂▁▁▁▁▅▄▁▃▄▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▃▁▁▁▇▁▁▁▁▁▁▁▂▁</td></tr><tr><td>val_loss_func_step</td><td>▂▁▁▂▁▁▅▂▂▂▁▂▁█▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▇▁▁▁▁▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss_class_epoch</td><td>0.00994</td></tr><tr><td>train_loss_class_step</td><td>0.00068</td></tr><tr><td>train_loss_func_epoch</td><td>0.0</td></tr><tr><td>train_loss_func_step</td><td>0.0</td></tr><tr><td>trainer/global_step</td><td>24999</td></tr><tr><td>val_loss_class_epoch</td><td>0.01091</td></tr><tr><td>val_loss_class_step</td><td>0.0</td></tr><tr><td>val_loss_func_epoch</td><td>1e-05</td></tr><tr><td>val_loss_func_step</td><td>2e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">electric-bee-23</strong> at: <a href='https://wandb.ai/harshg5799/lang-dataaugment/runs/ax8f1d7s' target="_blank">https://wandb.ai/harshg5799/lang-dataaugment/runs/ax8f1d7s</a><br/>Synced 6 W&B file(s), 1 media file(s), 100 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230831_184519-ax8f1d7s/logs</code>
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>./wandb/run-20230831_185048-fzzmi513</code>
# Syncing run <strong><a href='https://wandb.ai/harshg5799/lang-dataaugment/runs/fzzmi513' target="_blank">young-leaf-24</a></strong> to <a href='https://wandb.ai/harshg5799/lang-dataaugment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/harshg5799/lang-dataaugment' target="_blank">https://wandb.ai/harshg5799/lang-dataaugment</a>
#  View run at <a href='https://wandb.ai/harshg5799/lang-dataaugment/runs/fzzmi513' target="_blank">https://wandb.ai/harshg5799/lang-dataaugment/runs/fzzmi513</a>
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6]
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | augment_model | MLP              | 50.7 K
# 1 | class_model   | MLP              | 50.4 K
# 2 | func_model    | MLP              | 50.0 K
# 3 | loss          | CrossEntropyLoss | 0
# ---------------------------------------------------
# 50.7 K    Trainable params
# 100 K     Non-trainable params
# 151 K     Total params
# 0.605     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]torch.Size([2048]) torch.cuda.LongTensor
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 84.56it/s]torch.Size([2048]) torch.cuda.LongTensor
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:486: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/hg22723/anaconda3/envs/torch-2.0/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:281: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:   0%|          | 0/16 [00:00<?, ?it/s] torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:   6%|▋         | 1/16 [00:00<00:00, 21.57it/s, v_num=i513, train_loss_class_step=171.0]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  12%|█▎        | 2/16 [00:00<00:00, 23.13it/s, v_num=i513, train_loss_class_step=35.50]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  19%|█▉        | 3/16 [00:00<00:00, 25.11it/s, v_num=i513, train_loss_class_step=55.80]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  25%|██▌       | 4/16 [00:00<00:00, 26.46it/s, v_num=i513, train_loss_class_step=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  31%|███▏      | 5/16 [00:00<00:00, 27.24it/s, v_num=i513, train_loss_class_step=23.50]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  38%|███▊      | 6/16 [00:00<00:00, 28.18it/s, v_num=i513, train_loss_class_step=36.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  44%|████▍     | 7/16 [00:00<00:00, 28.84it/s, v_num=i513, train_loss_class_step=25.00]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  50%|█████     | 8/16 [00:00<00:00, 29.31it/s, v_num=i513, train_loss_class_step=20.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  56%|█████▋    | 9/16 [00:00<00:00, 29.78it/s, v_num=i513, train_loss_class_step=21.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  62%|██████▎   | 10/16 [00:00<00:00, 30.17it/s, v_num=i513, train_loss_class_step=19.50]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  69%|██████▉   | 11/16 [00:00<00:00, 30.37it/s, v_num=i513, train_loss_class_step=18.30]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  75%|███████▌  | 12/16 [00:00<00:00, 23.32it/s, v_num=i513, train_loss_class_step=16.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  81%|████████▏ | 13/16 [00:00<00:00, 23.85it/s, v_num=i513, train_loss_class_step=15.10]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  88%|████████▊ | 14/16 [00:00<00:00, 24.35it/s, v_num=i513, train_loss_class_step=12.30]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 0:  94%|█████████▍| 15/16 [00:00<00:00, 24.83it/s, v_num=i513, train_loss_class_step=10.40]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 0: 100%|██████████| 16/16 [00:00<00:00, 25.41it/s, v_num=i513, train_loss_class_step=6.180]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 1:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=6.180, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:   6%|▋         | 1/16 [00:00<00:00, 21.89it/s, v_num=i513, train_loss_class_step=3.880, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  12%|█▎        | 2/16 [00:00<00:00, 24.64it/s, v_num=i513, train_loss_class_step=3.150, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  19%|█▉        | 3/16 [00:00<00:00, 26.65it/s, v_num=i513, train_loss_class_step=3.620, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  25%|██▌       | 4/16 [00:00<00:00, 27.87it/s, v_num=i513, train_loss_class_step=2.950, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  31%|███▏      | 5/16 [00:00<00:00, 28.93it/s, v_num=i513, train_loss_class_step=1.270, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  38%|███▊      | 6/16 [00:00<00:00, 29.47it/s, v_num=i513, train_loss_class_step=0.00957, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  44%|████▍     | 7/16 [00:00<00:00, 29.91it/s, v_num=i513, train_loss_class_step=0.000148, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  50%|█████     | 8/16 [00:00<00:00, 30.24it/s, v_num=i513, train_loss_class_step=107.0, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]   torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  56%|█████▋    | 9/16 [00:00<00:00, 30.59it/s, v_num=i513, train_loss_class_step=2.530, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  62%|██████▎   | 10/16 [00:00<00:00, 30.85it/s, v_num=i513, train_loss_class_step=4.850, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  69%|██████▉   | 11/16 [00:00<00:00, 31.08it/s, v_num=i513, train_loss_class_step=11.30, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  75%|███████▌  | 12/16 [00:00<00:00, 23.75it/s, v_num=i513, train_loss_class_step=13.30, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  81%|████████▏ | 13/16 [00:00<00:00, 24.27it/s, v_num=i513, train_loss_class_step=16.80, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  88%|████████▊ | 14/16 [00:00<00:00, 24.77it/s, v_num=i513, train_loss_class_step=15.00, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 1:  94%|█████████▍| 15/16 [00:00<00:00, 25.21it/s, v_num=i513, train_loss_class_step=14.50, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 1: 100%|██████████| 16/16 [00:00<00:00, 25.78it/s, v_num=i513, train_loss_class_step=15.80, val_loss_class_step=4.050, val_loss_class_epoch=4.180, train_loss_class_epoch=33.20]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 2:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=15.80, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:   6%|▋         | 1/16 [00:00<00:00, 22.10it/s, v_num=i513, train_loss_class_step=15.80, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  12%|█▎        | 2/16 [00:00<00:00, 26.90it/s, v_num=i513, train_loss_class_step=13.60, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  19%|█▉        | 3/16 [00:00<00:00, 29.16it/s, v_num=i513, train_loss_class_step=13.90, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  25%|██▌       | 4/16 [00:00<00:00, 30.58it/s, v_num=i513, train_loss_class_step=16.30, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  31%|███▏      | 5/16 [00:00<00:00, 31.29it/s, v_num=i513, train_loss_class_step=16.50, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  38%|███▊      | 6/16 [00:00<00:00, 31.62it/s, v_num=i513, train_loss_class_step=15.30, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  44%|████▍     | 7/16 [00:00<00:00, 20.32it/s, v_num=i513, train_loss_class_step=14.00, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  50%|█████     | 8/16 [00:00<00:00, 21.34it/s, v_num=i513, train_loss_class_step=13.40, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  56%|█████▋    | 9/16 [00:00<00:00, 22.23it/s, v_num=i513, train_loss_class_step=15.70, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  62%|██████▎   | 10/16 [00:00<00:00, 22.00it/s, v_num=i513, train_loss_class_step=14.10, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  69%|██████▉   | 11/16 [00:00<00:00, 22.46it/s, v_num=i513, train_loss_class_step=14.30, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  75%|███████▌  | 12/16 [00:00<00:00, 22.90it/s, v_num=i513, train_loss_class_step=13.10, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  81%|████████▏ | 13/16 [00:00<00:00, 23.23it/s, v_num=i513, train_loss_class_step=15.70, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  88%|████████▊ | 14/16 [00:00<00:00, 23.59it/s, v_num=i513, train_loss_class_step=11.80, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 2:  94%|█████████▍| 15/16 [00:00<00:00, 23.85it/s, v_num=i513, train_loss_class_step=15.50, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 2: 100%|██████████| 16/16 [00:00<00:00, 24.37it/s, v_num=i513, train_loss_class_step=15.60, val_loss_class_step=16.40, val_loss_class_epoch=16.40, train_loss_class_epoch=13.40]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 3:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=15.60, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:   6%|▋         | 1/16 [00:00<00:00, 19.82it/s, v_num=i513, train_loss_class_step=13.30, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  12%|█▎        | 2/16 [00:00<00:00, 22.55it/s, v_num=i513, train_loss_class_step=9.760, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  19%|█▉        | 3/16 [00:00<00:00, 23.83it/s, v_num=i513, train_loss_class_step=8.890, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  25%|██▌       | 4/16 [00:00<00:00, 14.20it/s, v_num=i513, train_loss_class_step=7.550, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  31%|███▏      | 5/16 [00:00<00:00, 15.66it/s, v_num=i513, train_loss_class_step=7.450, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  38%|███▊      | 6/16 [00:00<00:00, 16.90it/s, v_num=i513, train_loss_class_step=7.570, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  44%|████▍     | 7/16 [00:00<00:00, 17.87it/s, v_num=i513, train_loss_class_step=11.30, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  50%|█████     | 8/16 [00:00<00:00, 18.69it/s, v_num=i513, train_loss_class_step=8.060, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  56%|█████▋    | 9/16 [00:00<00:00, 19.46it/s, v_num=i513, train_loss_class_step=7.720, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  62%|██████▎   | 10/16 [00:00<00:00, 20.08it/s, v_num=i513, train_loss_class_step=6.790, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  69%|██████▉   | 11/16 [00:00<00:00, 20.68it/s, v_num=i513, train_loss_class_step=7.210, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  75%|███████▌  | 12/16 [00:00<00:00, 21.15it/s, v_num=i513, train_loss_class_step=8.050, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  81%|████████▏ | 13/16 [00:00<00:00, 21.54it/s, v_num=i513, train_loss_class_step=7.940, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  88%|████████▊ | 14/16 [00:00<00:00, 21.87it/s, v_num=i513, train_loss_class_step=7.390, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 3:  94%|█████████▍| 15/16 [00:00<00:00, 22.23it/s, v_num=i513, train_loss_class_step=6.720, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 3: 100%|██████████| 16/16 [00:00<00:00, 22.71it/s, v_num=i513, train_loss_class_step=6.670, val_loss_class_step=12.80, val_loss_class_epoch=12.60, train_loss_class_epoch=14.60]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 4:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=6.670, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:   6%|▋         | 1/16 [00:00<00:00, 18.18it/s, v_num=i513, train_loss_class_step=6.650, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  12%|█▎        | 2/16 [00:00<00:00, 20.44it/s, v_num=i513, train_loss_class_step=8.350, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  19%|█▉        | 3/16 [00:00<00:00, 23.44it/s, v_num=i513, train_loss_class_step=7.810, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  25%|██▌       | 4/16 [00:00<00:00, 25.30it/s, v_num=i513, train_loss_class_step=6.420, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  31%|███▏      | 5/16 [00:00<00:00, 26.70it/s, v_num=i513, train_loss_class_step=6.930, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  38%|███▊      | 6/16 [00:00<00:00, 27.70it/s, v_num=i513, train_loss_class_step=6.550, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  44%|████▍     | 7/16 [00:00<00:00, 28.47it/s, v_num=i513, train_loss_class_step=6.490, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  50%|█████     | 8/16 [00:00<00:00, 28.78it/s, v_num=i513, train_loss_class_step=6.580, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  56%|█████▋    | 9/16 [00:00<00:00, 29.18it/s, v_num=i513, train_loss_class_step=5.450, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  62%|██████▎   | 10/16 [00:00<00:00, 29.44it/s, v_num=i513, train_loss_class_step=5.130, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  69%|██████▉   | 11/16 [00:00<00:00, 29.75it/s, v_num=i513, train_loss_class_step=4.910, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  75%|███████▌  | 12/16 [00:00<00:00, 30.07it/s, v_num=i513, train_loss_class_step=4.320, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  81%|████████▏ | 13/16 [00:00<00:00, 30.38it/s, v_num=i513, train_loss_class_step=4.310, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  88%|████████▊ | 14/16 [00:00<00:00, 30.60it/s, v_num=i513, train_loss_class_step=3.510, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 4:  94%|█████████▍| 15/16 [00:00<00:00, 30.80it/s, v_num=i513, train_loss_class_step=3.240, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 4: 100%|██████████| 16/16 [00:00<00:00, 31.30it/s, v_num=i513, train_loss_class_step=2.940, val_loss_class_step=6.470, val_loss_class_epoch=6.400, train_loss_class_epoch=8.310]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 5:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=2.940, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:   6%|▋         | 1/16 [00:00<00:00, 21.50it/s, v_num=i513, train_loss_class_step=2.600, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  12%|█▎        | 2/16 [00:00<00:00, 26.09it/s, v_num=i513, train_loss_class_step=2.600, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  19%|█▉        | 3/16 [00:00<00:00, 28.04it/s, v_num=i513, train_loss_class_step=1.640, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  25%|██▌       | 4/16 [00:00<00:00, 29.33it/s, v_num=i513, train_loss_class_step=1.530, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  31%|███▏      | 5/16 [00:00<00:00, 30.15it/s, v_num=i513, train_loss_class_step=1.720, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  38%|███▊      | 6/16 [00:00<00:00, 30.90it/s, v_num=i513, train_loss_class_step=1.530, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  44%|████▍     | 7/16 [00:00<00:00, 31.55it/s, v_num=i513, train_loss_class_step=1.340, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  50%|█████     | 8/16 [00:00<00:00, 31.72it/s, v_num=i513, train_loss_class_step=1.450, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  56%|█████▋    | 9/16 [00:00<00:00, 31.85it/s, v_num=i513, train_loss_class_step=1.180, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  62%|██████▎   | 10/16 [00:00<00:00, 31.96it/s, v_num=i513, train_loss_class_step=1.230, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  69%|██████▉   | 11/16 [00:00<00:00, 32.12it/s, v_num=i513, train_loss_class_step=1.180, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  75%|███████▌  | 12/16 [00:00<00:00, 32.26it/s, v_num=i513, train_loss_class_step=1.210, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  81%|████████▏ | 13/16 [00:00<00:00, 24.74it/s, v_num=i513, train_loss_class_step=1.100, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  88%|████████▊ | 14/16 [00:00<00:00, 25.17it/s, v_num=i513, train_loss_class_step=1.510, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 5:  94%|█████████▍| 15/16 [00:00<00:00, 25.56it/s, v_num=i513, train_loss_class_step=1.990, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 5: 100%|██████████| 16/16 [00:00<00:00, 26.15it/s, v_num=i513, train_loss_class_step=1.150, val_loss_class_step=2.450, val_loss_class_epoch=2.410, train_loss_class_epoch=5.660]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 6:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=1.150, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:   6%|▋         | 1/16 [00:00<00:00, 23.09it/s, v_num=i513, train_loss_class_step=1.170, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  12%|█▎        | 2/16 [00:00<00:00, 27.36it/s, v_num=i513, train_loss_class_step=1.550, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  19%|█▉        | 3/16 [00:00<00:00, 29.01it/s, v_num=i513, train_loss_class_step=1.960, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  25%|██▌       | 4/16 [00:00<00:00, 27.46it/s, v_num=i513, train_loss_class_step=0.822, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  31%|███▏      | 5/16 [00:00<00:00, 27.73it/s, v_num=i513, train_loss_class_step=1.760, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  38%|███▊      | 6/16 [00:00<00:00, 28.49it/s, v_num=i513, train_loss_class_step=1.130, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  44%|████▍     | 7/16 [00:00<00:00, 29.11it/s, v_num=i513, train_loss_class_step=1.250, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  50%|█████     | 8/16 [00:00<00:00, 29.67it/s, v_num=i513, train_loss_class_step=1.060, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  56%|█████▋    | 9/16 [00:00<00:00, 30.15it/s, v_num=i513, train_loss_class_step=1.390, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  62%|██████▎   | 10/16 [00:00<00:00, 22.21it/s, v_num=i513, train_loss_class_step=0.979, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  69%|██████▉   | 11/16 [00:00<00:00, 22.85it/s, v_num=i513, train_loss_class_step=1.210, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  75%|███████▌  | 12/16 [00:00<00:00, 23.55it/s, v_num=i513, train_loss_class_step=1.180, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  81%|████████▏ | 13/16 [00:00<00:00, 24.16it/s, v_num=i513, train_loss_class_step=1.060, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  88%|████████▊ | 14/16 [00:00<00:00, 24.71it/s, v_num=i513, train_loss_class_step=1.030, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 6:  94%|█████████▍| 15/16 [00:00<00:00, 25.16it/s, v_num=i513, train_loss_class_step=0.819, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 6: 100%|██████████| 16/16 [00:00<00:00, 25.77it/s, v_num=i513, train_loss_class_step=1.180, val_loss_class_step=1.230, val_loss_class_epoch=1.190, train_loss_class_epoch=1.570]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 7:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=1.180, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:   6%|▋         | 1/16 [00:00<00:00, 22.61it/s, v_num=i513, train_loss_class_step=0.958, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  12%|█▎        | 2/16 [00:00<00:00, 27.11it/s, v_num=i513, train_loss_class_step=0.795, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  19%|█▉        | 3/16 [00:00<00:00, 29.14it/s, v_num=i513, train_loss_class_step=0.827, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  25%|██▌       | 4/16 [00:00<00:00, 30.73it/s, v_num=i513, train_loss_class_step=1.220, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  31%|███▏      | 5/16 [00:00<00:00, 31.11it/s, v_num=i513, train_loss_class_step=0.891, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  38%|███▊      | 6/16 [00:00<00:00, 31.53it/s, v_num=i513, train_loss_class_step=0.809, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  44%|████▍     | 7/16 [00:00<00:00, 20.58it/s, v_num=i513, train_loss_class_step=1.320, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  50%|█████     | 8/16 [00:00<00:00, 21.54it/s, v_num=i513, train_loss_class_step=0.819, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  56%|█████▋    | 9/16 [00:00<00:00, 22.42it/s, v_num=i513, train_loss_class_step=3.090, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  62%|██████▎   | 10/16 [00:00<00:00, 23.20it/s, v_num=i513, train_loss_class_step=3.990, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  69%|██████▉   | 11/16 [00:00<00:00, 23.88it/s, v_num=i513, train_loss_class_step=5.790, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  75%|███████▌  | 12/16 [00:00<00:00, 24.42it/s, v_num=i513, train_loss_class_step=9.310, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  81%|████████▏ | 13/16 [00:00<00:00, 24.94it/s, v_num=i513, train_loss_class_step=9.140, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  88%|████████▊ | 14/16 [00:00<00:00, 25.38it/s, v_num=i513, train_loss_class_step=6.810, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 7:  94%|█████████▍| 15/16 [00:00<00:00, 25.76it/s, v_num=i513, train_loss_class_step=6.150, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 7: 100%|██████████| 16/16 [00:00<00:00, 26.33it/s, v_num=i513, train_loss_class_step=6.270, val_loss_class_step=0.952, val_loss_class_epoch=0.928, train_loss_class_epoch=1.220]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 8:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=6.270, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:   6%|▋         | 1/16 [00:00<00:00, 23.88it/s, v_num=i513, train_loss_class_step=6.880, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  12%|█▎        | 2/16 [00:00<00:00, 27.94it/s, v_num=i513, train_loss_class_step=8.290, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  19%|█▉        | 3/16 [00:00<00:00, 29.78it/s, v_num=i513, train_loss_class_step=6.300, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  25%|██▌       | 4/16 [00:00<00:00, 30.53it/s, v_num=i513, train_loss_class_step=5.310, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  31%|███▏      | 5/16 [00:00<00:00, 17.68it/s, v_num=i513, train_loss_class_step=5.700, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  38%|███▊      | 6/16 [00:00<00:00, 19.15it/s, v_num=i513, train_loss_class_step=5.610, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  44%|████▍     | 7/16 [00:00<00:00, 20.41it/s, v_num=i513, train_loss_class_step=5.650, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  50%|█████     | 8/16 [00:00<00:00, 21.46it/s, v_num=i513, train_loss_class_step=5.030, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  56%|█████▋    | 9/16 [00:00<00:00, 21.77it/s, v_num=i513, train_loss_class_step=4.960, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  62%|██████▎   | 10/16 [00:00<00:00, 22.56it/s, v_num=i513, train_loss_class_step=4.550, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  69%|██████▉   | 11/16 [00:00<00:00, 23.24it/s, v_num=i513, train_loss_class_step=6.340, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  75%|███████▌  | 12/16 [00:00<00:00, 23.85it/s, v_num=i513, train_loss_class_step=4.700, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  81%|████████▏ | 13/16 [00:00<00:00, 24.40it/s, v_num=i513, train_loss_class_step=4.500, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  88%|████████▊ | 14/16 [00:00<00:00, 24.94it/s, v_num=i513, train_loss_class_step=5.440, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 8:  94%|█████████▍| 15/16 [00:00<00:00, 25.50it/s, v_num=i513, train_loss_class_step=5.570, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 8: 100%|██████████| 16/16 [00:00<00:00, 26.10it/s, v_num=i513, train_loss_class_step=5.380, val_loss_class_step=6.330, val_loss_class_epoch=6.700, train_loss_class_epoch=3.570]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 9:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=5.380, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:   6%|▋         | 1/16 [00:00<00:00, 23.07it/s, v_num=i513, train_loss_class_step=5.550, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  12%|█▎        | 2/16 [00:00<00:00, 27.17it/s, v_num=i513, train_loss_class_step=5.670, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  19%|█▉        | 3/16 [00:00<00:00, 29.07it/s, v_num=i513, train_loss_class_step=5.600, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  25%|██▌       | 4/16 [00:00<00:00, 29.95it/s, v_num=i513, train_loss_class_step=5.580, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  31%|███▏      | 5/16 [00:00<00:00, 17.71it/s, v_num=i513, train_loss_class_step=5.540, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  38%|███▊      | 6/16 [00:00<00:00, 19.25it/s, v_num=i513, train_loss_class_step=4.480, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  44%|████▍     | 7/16 [00:00<00:00, 20.50it/s, v_num=i513, train_loss_class_step=3.400, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  50%|█████     | 8/16 [00:00<00:00, 21.58it/s, v_num=i513, train_loss_class_step=15.40, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  56%|█████▋    | 9/16 [00:00<00:00, 22.51it/s, v_num=i513, train_loss_class_step=3.140, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  62%|██████▎   | 10/16 [00:00<00:00, 23.31it/s, v_num=i513, train_loss_class_step=4.490, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  69%|██████▉   | 11/16 [00:00<00:00, 23.98it/s, v_num=i513, train_loss_class_step=4.950, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  75%|███████▌  | 12/16 [00:00<00:00, 24.55it/s, v_num=i513, train_loss_class_step=5.300, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  81%|████████▏ | 13/16 [00:00<00:00, 25.00it/s, v_num=i513, train_loss_class_step=5.240, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  88%|████████▊ | 14/16 [00:00<00:00, 25.45it/s, v_num=i513, train_loss_class_step=5.650, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 9:  94%|█████████▍| 15/16 [00:00<00:00, 25.86it/s, v_num=i513, train_loss_class_step=5.220, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 9: 100%|██████████| 16/16 [00:00<00:00, 26.44it/s, v_num=i513, train_loss_class_step=5.390, val_loss_class_step=5.650, val_loss_class_epoch=5.650, train_loss_class_epoch=5.640]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 10:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=5.390, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]        torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:   6%|▋         | 1/16 [00:00<00:02,  6.14it/s, v_num=i513, train_loss_class_step=5.120, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  12%|█▎        | 2/16 [00:00<00:01, 10.38it/s, v_num=i513, train_loss_class_step=4.880, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  19%|█▉        | 3/16 [00:00<00:00, 13.49it/s, v_num=i513, train_loss_class_step=4.940, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  25%|██▌       | 4/16 [00:00<00:00, 15.89it/s, v_num=i513, train_loss_class_step=4.460, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  31%|███▏      | 5/16 [00:00<00:00, 17.76it/s, v_num=i513, train_loss_class_step=4.260, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  38%|███▊      | 6/16 [00:00<00:00, 19.23it/s, v_num=i513, train_loss_class_step=3.870, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  44%|████▍     | 7/16 [00:00<00:00, 20.43it/s, v_num=i513, train_loss_class_step=2.770, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  50%|█████     | 8/16 [00:00<00:00, 21.38it/s, v_num=i513, train_loss_class_step=2.980, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  56%|█████▋    | 9/16 [00:00<00:00, 22.25it/s, v_num=i513, train_loss_class_step=3.960, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  62%|██████▎   | 10/16 [00:00<00:00, 22.99it/s, v_num=i513, train_loss_class_step=3.800, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  69%|██████▉   | 11/16 [00:00<00:00, 23.62it/s, v_num=i513, train_loss_class_step=4.660, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  75%|███████▌  | 12/16 [00:00<00:00, 24.21it/s, v_num=i513, train_loss_class_step=4.760, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  81%|████████▏ | 13/16 [00:00<00:00, 24.74it/s, v_num=i513, train_loss_class_step=5.050, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  88%|████████▊ | 14/16 [00:00<00:00, 25.24it/s, v_num=i513, train_loss_class_step=5.160, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 10:  94%|█████████▍| 15/16 [00:00<00:00, 25.64it/s, v_num=i513, train_loss_class_step=5.160, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 10: 100%|██████████| 16/16 [00:00<00:00, 26.21it/s, v_num=i513, train_loss_class_step=5.430, val_loss_class_step=5.330, val_loss_class_epoch=5.130, train_loss_class_epoch=5.670]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 11:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=5.430, val_loss_class_step=5.350, val_loss_class_epoch=5.180, train_loss_class_epoch=4.430]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 11:   6%|▋         | 1/16 [00:00<00:00, 21.49it/s, v_num=i513, train_loss_class_step=5.000, val_loss_class_step=5.350, val_loss_class_epoch=5.180, train_loss_class_epoch=4.430]torch.Size([2048]) torch.cuda.LongTensor
# ...
# Epoch 96:   6%|▋         | 1/16 [00:00<00:00, 22.26it/s, v_num=i513, train_loss_class_step=0.660, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  12%|█▎        | 2/16 [00:00<00:00, 26.60it/s, v_num=i513, train_loss_class_step=0.675, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  19%|█▉        | 3/16 [00:00<00:00, 28.41it/s, v_num=i513, train_loss_class_step=0.735, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  25%|██▌       | 4/16 [00:00<00:00, 27.71it/s, v_num=i513, train_loss_class_step=0.715, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  31%|███▏      | 5/16 [00:00<00:00, 27.86it/s, v_num=i513, train_loss_class_step=0.665, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  38%|███▊      | 6/16 [00:00<00:00, 28.75it/s, v_num=i513, train_loss_class_step=0.641, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  44%|████▍     | 7/16 [00:00<00:00, 19.27it/s, v_num=i513, train_loss_class_step=0.699, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  50%|█████     | 8/16 [00:00<00:00, 20.31it/s, v_num=i513, train_loss_class_step=0.665, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  56%|█████▋    | 9/16 [00:00<00:00, 21.22it/s, v_num=i513, train_loss_class_step=0.684, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  62%|██████▎   | 10/16 [00:00<00:00, 22.03it/s, v_num=i513, train_loss_class_step=0.642, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  69%|██████▉   | 11/16 [00:00<00:00, 22.77it/s, v_num=i513, train_loss_class_step=0.649, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  75%|███████▌  | 12/16 [00:00<00:00, 23.50it/s, v_num=i513, train_loss_class_step=0.659, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  81%|████████▏ | 13/16 [00:00<00:00, 24.10it/s, v_num=i513, train_loss_class_step=0.703, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  88%|████████▊ | 14/16 [00:00<00:00, 24.55it/s, v_num=i513, train_loss_class_step=0.717, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 96:  94%|█████████▍| 15/16 [00:00<00:00, 24.90it/s, v_num=i513, train_loss_class_step=0.734, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 96: 100%|██████████| 16/16 [00:00<00:00, 25.48it/s, v_num=i513, train_loss_class_step=0.727, val_loss_class_step=0.641, val_loss_class_epoch=0.651, train_loss_class_epoch=0.666]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 97:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=0.727, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:   6%|▋         | 1/16 [00:00<00:00, 19.67it/s, v_num=i513, train_loss_class_step=0.983, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  12%|█▎        | 2/16 [00:00<00:00, 24.71it/s, v_num=i513, train_loss_class_step=0.593, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  19%|█▉        | 3/16 [00:00<00:01, 12.60it/s, v_num=i513, train_loss_class_step=0.756, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  25%|██▌       | 4/16 [00:00<00:00, 15.05it/s, v_num=i513, train_loss_class_step=0.776, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  31%|███▏      | 5/16 [00:00<00:00, 16.98it/s, v_num=i513, train_loss_class_step=0.626, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  38%|███▊      | 6/16 [00:00<00:00, 18.52it/s, v_num=i513, train_loss_class_step=0.885, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  44%|████▍     | 7/16 [00:00<00:00, 19.81it/s, v_num=i513, train_loss_class_step=0.649, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  50%|█████     | 8/16 [00:00<00:00, 20.86it/s, v_num=i513, train_loss_class_step=0.741, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  56%|█████▋    | 9/16 [00:00<00:00, 21.72it/s, v_num=i513, train_loss_class_step=0.634, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  62%|██████▎   | 10/16 [00:00<00:00, 22.44it/s, v_num=i513, train_loss_class_step=0.840, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  69%|██████▉   | 11/16 [00:00<00:00, 23.11it/s, v_num=i513, train_loss_class_step=0.689, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  75%|███████▌  | 12/16 [00:00<00:00, 23.74it/s, v_num=i513, train_loss_class_step=0.706, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  81%|████████▏ | 13/16 [00:00<00:00, 24.24it/s, v_num=i513, train_loss_class_step=0.643, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  88%|████████▊ | 14/16 [00:00<00:00, 24.64it/s, v_num=i513, train_loss_class_step=0.718, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 97:  94%|█████████▍| 15/16 [00:00<00:00, 24.99it/s, v_num=i513, train_loss_class_step=0.679, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 97: 100%|██████████| 16/16 [00:00<00:00, 25.51it/s, v_num=i513, train_loss_class_step=0.727, val_loss_class_step=0.895, val_loss_class_epoch=0.962, train_loss_class_epoch=0.685]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 98:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=0.727, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:   6%|▋         | 1/16 [00:00<00:00, 18.64it/s, v_num=i513, train_loss_class_step=0.664, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  12%|█▎        | 2/16 [00:00<00:00, 23.40it/s, v_num=i513, train_loss_class_step=0.720, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  19%|█▉        | 3/16 [00:00<00:00, 26.03it/s, v_num=i513, train_loss_class_step=0.705, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  25%|██▌       | 4/16 [00:00<00:00, 27.51it/s, v_num=i513, train_loss_class_step=0.776, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  31%|███▏      | 5/16 [00:00<00:00, 28.60it/s, v_num=i513, train_loss_class_step=0.748, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  38%|███▊      | 6/16 [00:00<00:00, 29.23it/s, v_num=i513, train_loss_class_step=0.720, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  44%|████▍     | 7/16 [00:00<00:00, 29.73it/s, v_num=i513, train_loss_class_step=0.616, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  50%|█████     | 8/16 [00:00<00:00, 30.09it/s, v_num=i513, train_loss_class_step=0.702, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  56%|█████▋    | 9/16 [00:00<00:00, 30.32it/s, v_num=i513, train_loss_class_step=0.641, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  62%|██████▎   | 10/16 [00:00<00:00, 30.47it/s, v_num=i513, train_loss_class_step=0.642, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  69%|██████▉   | 11/16 [00:00<00:00, 30.59it/s, v_num=i513, train_loss_class_step=0.706, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  75%|███████▌  | 12/16 [00:00<00:00, 30.71it/s, v_num=i513, train_loss_class_step=0.625, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  81%|████████▏ | 13/16 [00:00<00:00, 30.85it/s, v_num=i513, train_loss_class_step=0.682, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  88%|████████▊ | 14/16 [00:00<00:00, 30.86it/s, v_num=i513, train_loss_class_step=0.753, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 98:  94%|█████████▍| 15/16 [00:00<00:00, 30.96it/s, v_num=i513, train_loss_class_step=0.725, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 98: 100%|██████████| 16/16 [00:00<00:00, 31.35it/s, v_num=i513, train_loss_class_step=0.627, val_loss_class_step=0.643, val_loss_class_epoch=0.646, train_loss_class_epoch=0.728]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 99:   0%|          | 0/16 [00:00<?, ?it/s, v_num=i513, train_loss_class_step=0.627, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]         torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:   6%|▋         | 1/16 [00:00<00:00, 22.08it/s, v_num=i513, train_loss_class_step=0.758, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  12%|█▎        | 2/16 [00:00<00:00, 26.18it/s, v_num=i513, train_loss_class_step=0.770, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  19%|█▉        | 3/16 [00:00<00:00, 27.73it/s, v_num=i513, train_loss_class_step=0.872, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  25%|██▌       | 4/16 [00:00<00:00, 28.67it/s, v_num=i513, train_loss_class_step=0.718, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  31%|███▏      | 5/16 [00:00<00:00, 29.60it/s, v_num=i513, train_loss_class_step=0.698, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  38%|███▊      | 6/16 [00:00<00:00, 30.06it/s, v_num=i513, train_loss_class_step=0.640, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  44%|████▍     | 7/16 [00:00<00:00, 30.41it/s, v_num=i513, train_loss_class_step=0.657, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  50%|█████     | 8/16 [00:00<00:00, 30.64it/s, v_num=i513, train_loss_class_step=0.671, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  56%|█████▋    | 9/16 [00:00<00:00, 30.74it/s, v_num=i513, train_loss_class_step=0.724, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  62%|██████▎   | 10/16 [00:00<00:00, 30.79it/s, v_num=i513, train_loss_class_step=0.677, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  69%|██████▉   | 11/16 [00:00<00:00, 30.01it/s, v_num=i513, train_loss_class_step=0.743, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  75%|███████▌  | 12/16 [00:00<00:00, 22.90it/s, v_num=i513, train_loss_class_step=0.622, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  81%|████████▏ | 13/16 [00:00<00:00, 23.40it/s, v_num=i513, train_loss_class_step=0.831, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  88%|████████▊ | 14/16 [00:00<00:00, 23.95it/s, v_num=i513, train_loss_class_step=0.651, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# Epoch 99:  94%|█████████▍| 15/16 [00:00<00:00, 24.45it/s, v_num=i513, train_loss_class_step=0.714, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([1280]) torch.cuda.LongTensor
# Epoch 99: 100%|██████████| 16/16 [00:00<00:00, 24.70it/s, v_num=i513, train_loss_class_step=0.641, val_loss_class_step=0.777, val_loss_class_epoch=0.736, train_loss_class_epoch=0.692]torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([2048]) torch.cuda.LongTensor
# torch.Size([1856]) torch.cuda.LongTensor
# Epoch 99: 100%|██████████| 16/16 [00:00<00:00, 21.17it/s, v_num=i513, train_loss_class_step=0.641, val_loss_class_step=0.737, val_loss_class_epoch=0.772, train_loss_class_epoch=0.713]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 16/16 [00:01<00:00,  9.87it/s, v_num=i513, train_loss_class_step=0.641, val_loss_class_step=0.737, val_loss_class_epoch=0.772, train_loss_class_epoch=0.713]

# %%
# Visualization of the augmentations on the training data

#Load the model and the augmented model
T = 3
aug_model = augmentTrainer(input_size=2,hidden_size=128,output_size=4, 
                       class_modelweights = model.return_model_weights()[0], 
                       func_modelweights = model.return_model_weights()[1],
                       T = T)
aug_model.load_state_dict(torch.load('augmodel.pt'))

augment_model = MLP(2 + NCLASSES, 128, output_size = 2, num_layers = 3, tanh = True)
augment_model.load_state_dict(aug_model.return_model_weights())

# Take the same samples from the training dataset and visualize the augmentations

x_vis_train_data = [x_train[np.where(y_class_train == 0)[0][:100]], 
                    x_train[np.where(y_class_train == 1)[0][:100]],
                    x_train[np.where(y_class_train == 2)[0][:100]],
                    x_train[np.where(y_class_train == 3)[0][:100]]]


for ds_j,ds in enumerate(x_vis_train_data):
    frames = []

    target_class = np.concatenate([(np.zeros(ds.shape[0]) + j) for j in range(NCLASSES)],axis=0)
    target_class = torch.tensor(target_class).type(torch.LongTensor)

    x = torch.repeat_interleave(torch.tensor(ds, dtype = torch.float32), NCLASSES, dim = 0)

    target_class_onehot = torch.nn.functional.one_hot(target_class, num_classes = NCLASSES)
    input = torch.cat((x, target_class_onehot), dim = 1)
    augment_list = [x.cpu().detach().numpy()]
    for j in range(T):
        augment = augment_model(input)
        x = x + augment
        augment_list.append(x.cpu().detach().numpy())
    
    frames = []
    for j,aug in enumerate(augment_list):
        # Split the augmented data per the target class for plotting
        aug_split = np.split(aug, NCLASSES, axis = 0)
        fig, axs = plt.subplots(1, NCLASSES, figsize=(16, 4))
        # set the axis limits to range
        for i in range(NCLASSES):
            axs[i].set_xlim([RANGE[0], RANGE[1]])
            axs[i].set_ylim([RANGE[0],RANGE[1]])  


        if j ==0:
            color = 'blue'
        else:
            color = 'red'
        for i in range(NCLASSES):
            axs[i].scatter(aug_split[i][:, 0], aug_split[i][:, 1], s = 1, color = color)
            axs[i].set_title(f'Data Moves to target Class {i}')
        buf = BytesIO()
        plt.savefig(buf, format='png')
        plt.close(fig)
        buf.seek(0)
        im = Image.open(buf)
        frames.append(np.array(im))
        buf.close()

    import os
    if not os.path.exists('results_T{}'.format(T)):
        os.makedirs('results_T{}'.format(T))
    # Create the GIF
    imageio.mimsave('results_T{}/animated{}.gif'.format(T,ds_j), frames, duration=5.0, loop = 0)
# Out:
# /tmp/ipykernel_1353204/2351223166.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.repeat_interleave(torch.tensor(ds, dtype = torch.float32), NCLASSES, dim = 0)
